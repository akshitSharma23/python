# %%
from IPython.display import clear_output
def disp(a):
    #clear_output()
    print(' _ _ _')
    print(f'|{a[7]}|{a[8]}|{a[9]}|')
    print(f'|{a[4]}|{a[5]}|{a[6]}|')
    print(f'|{a[1]}|{a[2]}|{a[3]}|')

# %%
def play_1():
    print('time to select sign')
    
    
    while True:
        i=input('player 1 select your sign X or O ')
        if i in ['x','X','o','O']:
            break
        else:
            print('invalid input')
            continue
    i=i.upper()
    if i=='X':
        p='O'
        print('player 1 paly with X sign')
        print('player 2 paly with O sign')
    if i=='O':
        p='X'
        print('player 1 play with O sign')
        print('plyer 2 paly with X sign')
    return (i,p)

# %%
def player_choice ():
    global p1
    global p2
    p1,p2=play_1()

# %%
def turn_1():        
    pp1=p1
    print('player 1 Turn')
    while True: 
        inp=input('player 1 has to select the location from num pad')
        if inp.isdigit()==True:
            inp=int(inp)
            if inp in range(1,10):
                if inp in lst:
                    print('you can\'t overwrite')
                    continue 
                if inp not in lst:
                    q[inp]=pp1
                    lst.append(inp)
                    disp(q)
                    break
            else:
                print('number should be in range')
                continue
        else:
            print('enter a numeric value')
            continue

# %%
from random import choices
def turn_2():
    pp2=p2
    print('player 2 Turn')
    while True:
        wi=wins(pp2)
        #print(wi)
        if(wi==-1):
            bl=block(p1)
            if(bl==-1):
                inp=choices(d)
                inp=inp[0]
            else:
                inp=bl
        else:
            inp=wi
        #print(inp)
        if inp in range(1,10):
                if inp in lst:
                    continue 
                if inp not in lst:
                    q[inp]=pp2
                    lst.append(inp)
                    d.remove(inp)
                    disp(q)
                    break
        else:
                print('number should be in range')
                break

# %%
def wins(p):
    a=q
    #print(a[7])
    if(a[7]==p and a[4]==p and a[1]=='_'):
        return 1
    if(a[7]==p and a[4]=='_' and a[1]==p):
        return 4
    if(a[7]=='_' and a[4]==p and a[1]==p):
        return 7
    if(a[8]==p and a[5]==p and a[2]=='_'):
        return 2
    if(a[8]==p and a[5]=='_' and a[2]==p):
        return 5
    if(a[8]=='_' and a[5]==p and a[2]==p):
        return 8
    if(a[9]==p and a[6]==p and a[3]=='_'):
        return 3
    if(a[9]==p and a[6]=='_' and a[3]==p):
        return 6
    if(a[9]=='_' and a[6]==p and a[3]==p):
        return 9
    if(a[7]=='_' and a[8]==p and a[9]==p):
        return 7
    if(a[7]==p and a[8]=='_' and a[9]==p):
        return 8
    if(a[7]==p and a[8]==p and a[9]=='_'):
        return 9
    if(a[4]=='_' and a[5]==p and a[6]==p):
        return 4
    if(a[4]==p and a[5]=='_' and a[6]==p):
        return 5
    if(a[4]==p and a[5]==p and a[6]=='_'):
        return 6
    if(a[1]=='_' and a[2]==p and a[3]==p):
        return 1
    if(a[1]==p and a[2]=='_' and a[3]==p):
        return 2
    if(a[1]==p and a[2]==p and a[3]=='_'):
        return 3
    if(a[1]=='_' and a[5]==p and a[9]==p):
        return 1
    if(a[1]==p and a[5]=='_' and a[9]==p):
        return 5
    if(a[1]==p and a[5]==p and a[9]=='_'):
        return 9
    if(a[7]=='_' and a[5]==p and a[3]==p):
        return 7
    if(a[7]==p and a[5]=='_' and a[3]==p):
        return 5
    if(a[7]==p and a[5]==p and a[3]=='_'):
        return 3
    else:
        return(-1)

# %%
def block(p):
    a=q
    #print(p)
    if(a[7]==p and a[4]==p and a[1]=='_'):
        return 1
    if(a[7]==p and a[4]=='_' and a[1]==p):
        return 4
    if(a[7]=='_' and a[4]==p and a[1]==p):
        return 7
    if(a[8]==p and a[5]==p and a[2]=='_'):
        return 2
    if(a[8]==p and a[5]=='_' and a[2]==p):
        return 5
    if(a[8]=='_' and a[5]==p and a[2]==p):
        return 8
    if(a[9]==p and a[6]==p and a[3]=='_'):
        return 3
    if(a[9]==p and a[6]=='_' and a[3]==p):
        return 6
    if(a[9]=='_' and a[6]==p and a[3]==p):
        return 9
    if(a[7]=='_' and a[8]==p and a[9]==p):
        return 7
    if(a[7]==p and a[8]=='_' and a[9]==p):
        return 8
    if(a[7]==p and a[8]==p and a[9]=='_'):
        return 9
    if(a[4]=='_' and a[5]==p and a[6]==p):
        return 4
    if(a[4]==p and a[5]=='_' and a[6]==p):
        return 5
    if(a[4]==p and a[5]==p and a[6]=='_'):
        return 6
    if(a[1]=='_' and a[2]==p and a[3]==p):
        return 1
    if(a[1]==p and a[2]=='_' and a[3]==p):
        return 2
    if(a[1]==p and a[2]==p and a[3]=='_'):
        return 3
    if(a[1]=='_' and a[5]==p and a[9]==p):
        return 1
    if(a[1]==p and a[5]=='_' and a[9]==p):
        return 5
    if(a[1]==p and a[5]==p and a[9]=='_'):
        return 9
    if(a[7]=='_' and a[5]==p and a[3]==p):
        return 7
    if(a[7]==p and a[5]=='_' and a[3]==p):
        return 5
    if(a[7]==p and a[5]==p and a[3]=='_'):
        return 3
    else:
        return(-1)

# %%
def horizo_1(a):
    i=p1
    if i in a[7] and i in a[8] and i in a[9]:
        return 1
    if i in a[4] and i in a[5] and i in a[6]:
        return 1
    if i in a[1] and i in a[2] and i in a[3]:
        return 1
    else:
        return 0

# %%
def vertical_1(a):
    i=p1
    if i in a[7] and i in a[4] and i in a[1]:
        return 1
    if i in a[8] and i in a[5] and i in a[2]:
        return 1
    if i in a[9] and i in a[6] and i in a[3]:
        return 1
    else:
        return 0

# %%
def diagonal_1(a):
    i=p1
    if i in a[7] and i in a[5] and i in a[3]:
        return 1
    if i in a[9] and i in a[5] and i in a[1]:
        return 1
    else:
        return 0

# %%
def horizo_2(a):
    j=p2
    if j in a[7] and j in a[8] and j in a[9]:
        return 2
    if j in a[4] and j in a[5] and j in a[6]:
        return 2
    if j in a[1] and j in a[2] and j in a[3]:
        return 2
    else:
        return 0

# %%
def vertical_2(a):
    j=p2
    if j in a[7] and j in a[4] and j in a[1]:
        return 2
    if j in a[8] and j in a[5] and j in a[2]:
        return 2
    if j in a[9] and j in a[6] and j in a[3]:
        return 2
    else:
        return 0

# %%
def diagonal_2(a):
    j=p2
    if j in a[7] and j in a[5] and j in a[3]:
        return 2
    if j in a[9] and j in a[5] and j in a[1]:
        return 2
    else:
        return 0

# %%
def rev():
    global q
    global lst
    player_choice()
    q=['_']*10
    lst=[]
    l=1
    global d
    d=list(range(1,10))
    turn_1()
    while l<9:
            turn_2()
            w=horizo_2(q)
            w1=vertical_2(q)
            w2=diagonal_2(q)
            if w==2 or w1==2 or w2==2:
                print('player 2 has won the game')
                return('game is ended')
            l+=1
            turn_1()
            j=horizo_1(q)
            j1=vertical_1(q)
            j2=diagonal_1(q)
            if j==1 or j1==1 or j2==1:
                print('player 1 has won the game')
                return('the game is ended')
            l+=1
    print('it\'s a draw')
    return('game is ended')

# %%
rev()
# Out:
# time to select sign
# player 1 select your sign X or O x
# player 1 paly with X sign
# player 2 paly with O sign
# player 1 Turn

# %%
d=list(range(1,10))
inp=choices(d)
inp=inp[0]
print(inp)
# Out:
# 2
