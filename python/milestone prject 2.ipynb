# %%
import random
suit=('Diamond','Hearts','Clubs','Spades')
rank=('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')
value={'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':11,'Queen':12,'King':13,'Ace':14}

# %%
class card():
    def __init__(i,suit,rank):
        i.suit=suit
        i.rank=rank
        i.value=value[rank]
    def __str__(i):
        return (f'{i.rank} {i.suit}')

# %%
c=card('diamond','Five')

# %%
print(c)
# Out:
# Five diamond

# %%
value['Jack']
# Out:
# 11

# %%
print(values['King'])
# Out:
# 13

# %%
class deck():
    def __init__(self):
        self.dek=[]
        for i in suit:
            for j in rank:
                create=card(i,j)
                self.dek.append(create)
    def shufle(self):
        random.shuffle(self.dek)
    def POP(self):
        return self.dek.pop()

# %%
d=deck()

# %%
d.shufle()

# %%
#print(len(d.dek))
k=d.POP()

# %%
print(k)
# Out:
# Six Hearts

# %%
#print(len(d.dek))
for i in d.dek:
    print(i)
# Out:
# Five Hearts
# Three Hearts
# Three Clubs
# Nine Diamond
# Five Diamond
# Queen Diamond
# Two Spades
# Seven Spades
# Ace Spades
# Three Diamond
# Two Hearts
# King Clubs
# Six Diamond
# Eight Hearts
# Ten Spades
# Queen Hearts
# King Diamond
# Two Diamond
# Seven Diamond
# Jack Hearts
# Ten Clubs
# Two Clubs
# Five Clubs
# Ten Diamond
# Queen Spades
# Jack Diamond
# Jack Spades
# Eight Spades
# Four Diamond
# Nine Clubs
# Queen Clubs
# Four Hearts
# Nine Hearts
# Six Spades
# Ten Hearts
# Eight Clubs
# Eight Diamond
# Three Spades
# Jack Clubs
# Seven Clubs
# Four Spades
# King Spades
# Seven Hearts
# Four Clubs
# Ace Diamond
# King Hearts
# Ace Clubs
# Six Clubs
# Five Spades
# Nine Spades
# Ace Hearts

# %%
class player():
    def __init__(self,name):
        self.name=name
        self.all=[]
    def remove_one(self):
        return(self.all.pop(0))
    def  add_cards(self,new_card):
        if type(new_card)==type([]):
            self.all.extend(new_card)
        else:
            self.all.append(new_card)
    def __str__(self):
        return(f'player {self.name} had {len(self.all)} cards')

# %%
new_=player('akshit')

# %%
print(c)
# Out:
# Five diamond

# %%
new_.add_cards([c,c,c,c,c])

# %%
new_.remove_one()

# %%
print(new_)
# Out:
# player akshit had 4 cards

# %%
player_1=player('one')
player_2=player('two')
d=deck()
d.shufle()
for i in range(26):
    player_1.add_cards(d.POP())
    player_2.add_cards(d.POP())
print(player_1)
print(player_2)
# Out:
# player one had 26 cards
# player two had 26 cards

# %%
game=True
while game==True:
    if len(player_1.all)==0:
        print('player_1 has lost the game')
        break

    if len(player_2.all)==0:
        print('player_2 has lost the game')
        break

    table1=[]
    table1.append(player_1.remove_one())
    table2=[]
    table2.append(player_2.remove_one())
    #print(table1[-1], table1[-1].value)4
    #print(table2[-1], table2[-1].value)

    while True:
        if table1[-1].value>table2[-1].value:
            print('player_1 has won the table')
            player_1.add_cards(table1)
            player_1.add_cards(table2)
            break
        elif table1[-1].value<table2[-1].value:
            print('player_2 has won the table')
            player_2.add_cards(table1)
            player_2.add_cards(table2)
            break
        else:
            print('WAR')
            if len(player_1.all)<5:
                print('player_1 has less card')
                print('player_1 lost the game')
                print('Congratulation player_2')
                game=False
                break            
            if len(player_2.all)<5:
                print('player_2 has less card')
                print('player_2 lost the game')
                print('Congratulation player_1')
                game=False
                break   
            else:
                for i in range(5):
                    table1.append(player_1.remove_one())
                    table2.append(player_2.remove_one())
# Out:
# player_1 has won the table
# player_2 has won the table
# player_1 has won the table
# player_1 has won the table
# player_2 has won the table
# player_2 has won the table
# player_1 has won the table
# player_2 has won the table
# player_2 has won the table
# player_1 has won the table
# player_2 has won the table
# player_1 has won the table
# player_1 has won the table
# player_2 has won the table
# player_1 has won the table
# WAR
# player_2 has won the table
# player_2 has won the table
# player_1 has won the table
# player_2 has won the table
# player_2 has won the table
# player_1 has won the table
# player_2 has won the table
# player_2 has won the table
# player_1 has won the table
# player_2 has won the table
# player_1 has won the table
# player_2 has won the table
# player_1 has won the table
# player_2 has won the table
# player_1 has won the table
# player_2 has won the table
# player_1 has won the table
# player_1 has won the table
# player_1 has won the table
# ...

# %%
value['Two']
# Out:
# 2

# %%
import random
suit=('Diamond','Hearts','Clubs','Spades')
rank=('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')
value={'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':11,'Queen':12,'King':13,'Ace':14}

# %%
class card():
    def __init__(i,suit,rank):
        i.suit=suit
        i.rank=rank
        i.value=value[rank]
    def __str__(i):
        return (f'{i.rank} {i.suit}')

# %%
class deck():
    def __init__(self):
        self.dek=[]
        for i in n_suit:
            for j in n_rank:
                create=card(i,j)
                self.dek.append(create)
    def shufle(self):
        random.shuffle(self.dek)
    def POP(self):
        crd=self.dek.pop()
        return crd

# %%
class player():
    def __init__(self,name):
        self.name=name
        self.all=[]
    def remove_one(self):
        return(self.all.pop(0))
    def  add_cards(self,new_card):
        if type(new_card)==type([]):
            self.all.extend(new_card)
        else:
            self.all.append(new_card)
    def __str__(self):
        return(f'player {self.name} had {len(self.all)} cards')
